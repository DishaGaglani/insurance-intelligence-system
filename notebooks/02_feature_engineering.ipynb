# %% [markdown]
# # 02 - Feature Engineering
# Build and validate candidate features for risk, loss, and fraud models.

# %%
import pandas as pd
from src.feature_engineering import build_features
df = pd.DataFrame()
build_features(df).head()
